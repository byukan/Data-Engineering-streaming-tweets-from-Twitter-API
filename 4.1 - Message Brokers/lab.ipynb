# %%
#!/usr/bin/env python

"""
    @file twitter_firehose_kinesis.py

        set up firehose delivery stream http://docs.aws.amazon.com/firehose/latest/dev/basic-create.html#console-to
        -s3 S3 Bucket: justw149 ssh -i ~/.ssh/the_cloud.pem ubuntu@ec2-54-161-219-252.compute-1.amazonaws.com scp -i
        ~/the_cloud.pem twitter_firehose_kinesis.py ubuntu@ec2-54-161-219-252.compute-1.amazonaws.com:/home/ubuntu/

        ubuntu:
            sudo apt install awscli
            aws configure
            pip install boto3
            nohup python twitter_firehose_kinesis.py&
"""

import boto3
import os
import yaml
import json
from twitter import TwitterStream, OAuth


def firehose_tweets(twitter_stream):
    """
    INPUT: twitter_stream object.
    OUTPUT: tweets in json format inserted in S3 using Kinesis.
    """
    iterator = twitter_stream.statuses.sample()
    for tweet in iterator:
        if 'id' in tweet:
            try:
                response = firehose_client.put_record(
                    DeliveryStreamName='twitter_firehose',
                    Record={'Data': json.dumps(str(tweet) + '\n')})
                print(response)
            except Exception:
                print("Did not work.")


if __name__ == '__main__':

    credentials = yaml.load(open(os.path.expanduser('~/api_cred.yml')))
    firehose_client = boto3.client('firehose', region_name='us-east-1')
    twitter_stream = TwitterStream(auth=OAuth(**credentials['twitter']))

    while True:
        firehose_tweets(twitter_stream)
# Out:
# {u'RecordId': u'v2NDAYSB6sm2GVuXBTr38ee8+hp4A0tZYJP2ppsfw2M6NyjEusFPFSwvmuXF2A+Zvns4se9oyj/0bzvV09ZxAFXZYQaw30Z4Utb1O9HhJrGs/mtrvlx6Gw09etIPpOMRJ/VwMdjH4DBpRnqsazX9fiukvxMg76vSV6T3BdrBaf7kdHk1KyNZIUDDAfzk6sSc0N0tYYtbc3PPZ9PPfPXksOK7gdxqHr5A', 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd4f2f085-ecdc-11e6-888e-330f72e5c00c', 'HTTPHeaders': {'x-amzn-requestid': 'd4f2f085-ecdc-11e6-888e-330f72e5c00c', 'x-amz-id-2': 'uk5T67104czxbaOv5/5pBl5ZQImgqHSW5nWedsoFqfw91FpgmCX5k8Up507w2rolZ3JvwlniPfPnegxT43hcrW5ehfJAnAA2', 'content-length': '239', 'content-type': 'application/x-amz-json-1.1', 'date': 'Tue, 07 Feb 2017 02:26:28 GMT'}}}
# {u'RecordId': u'B+h3WaE8hr+8HLL00UKs/baulsrTlguNehUcbrEGB6lu3I4ndjYuazIwSyUl2YRqlBXgJN80EGOM4DoMjl/NCW7Ttk8YQWAEnv/dmIo7e2M2hn6dHJGO0cXUiPYQ6PzLwRPhlnaxuurJCWhVNM425DnwseCafeu0SonIIJar4zS143l2GzYiXVVrXbC06FfFLSn/oI7UIlXX+psgTSCH64hRRZ6NzArI', 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd510637b-ecdc-11e6-888e-330f72e5c00c', 'HTTPHeaders': {'x-amzn-requestid': 'd510637b-ecdc-11e6-888e-330f72e5c00c', 'x-amz-id-2': 'qUZMK1wKwFKN+CGmNK8ypR/rlXiX3m4vLwzLb+p644iZ300MHYL7QUXNoPH8I2zQLmtKLs19GuLy/XzrqTl2/ZscZ4a62iBt', 'content-length': '239', 'content-type': 'application/x-amz-json-1.1', 'date': 'Tue, 07 Feb 2017 02:26:29 GMT'}}}
# {u'RecordId': u'PY1hj53bIiHma2TNfrUI0Z8jeWrgk9FmQumGy3ytzH0DmRtS0PeCr9Oj2h2E00IHDkc1AdZX18kCmOf06l1dt78rWZJzujYRCTUjTnp0Qz8KfqJpsi3ehuwzJ5wDTRZBL7YXYKzq7SA+n5nc9s1Dt1KlbsoHvfRaU2Pvf+NbbN6xwheAVllaOXu/LnN0cmanyqinrZ29rI4W2vMLHfX7cQJ1K4KYDMN8', 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '
atusCode': 200, 'RequestId': 'd6dc97c9-ecdc-11e6-888e-330f72e5c00c', 'HTTPHeaders': {'x-amzn-requestid': 'd6dc97c9-ecdc-11e6-888e-330f72e5c00c', 'x-amz-id-2': 'JW06fZ1y1NPbf3ozJq+Wz0U9t474m0fd4/KyLUcilQFPi5fqygTUnPBzuB579I6iOtkpDvBmPLE2qo1ibJ44LXgr4+upktz3', 'content-length': '239', 'content-type': 'application/x-amz-json-1.1', 'date': 'Tue, 07 Feb 2017 02:26:32 GMT'}}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f84539d4f2ff> in <module>()
#      46
#      47     while True:
# ---> 48         firehose_tweets(twitter_stream)
#
# <ipython-input-8-f84539d4f2ff> in firehose_tweets(twitter_stream)
#      33                 response = firehose_client.put_record(
#      34                     DeliveryStreamName='twitter_firehose',
# ---> 35                     Record={'Data': json.dumps(str(tweet) + '\n')})
#      36                 print(response)
#      37             except Exception:
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/client.pyc in _api_call(self, *args, **kwargs)
#     251                     "%s() only accepts keyword arguments." % py_operation_name)
#     252             # The "self" in this scope is referring to the BaseClient.
# --> 253             return self._make_api_call(operation_name, kwargs)
#     254
#     255         _api_call.__name__ = str(py_operation_name)
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/client.pyc in _make_api_call(self, operation_name, api_params)
#     528         else:
#     529             http, parsed_response = self._endpoint.make_request(
# --> 530                 operation_model, request_dict)
#     531
#     532         self.meta.events.emit(
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/endpoint.pyc in make_request(self, operation_model, request_dict)
#     139         logger.debug("Making request for %s (verify_ssl=%s) with params: %s",
#     140                      operation_model, self.verify, request_dict)
# --> 141         return self._send_request(request_dict, operation_model)
#     142
#     143     def create_request(self, params, operation_model=None):
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/endpoint.pyc in _send_request(self, request_dict, operation_model)
#     166         request = self.create_request(request_dict, operation_model)
#     167         success_response, exception = self._get_response(
# --> 168             request, operation_model, attempts)
#     169         while self._needs_retry(attempts, operation_model, request_dict,
#     170                                 success_response, exception):
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/endpoint.pyc in _get_response(self, request, operation_model, attempts)
#     202                 request, verify=self.verify,
#     203                 stream=operation_model.has_streaming_output,
# --> 204                 proxies=self.proxies, timeout=self.timeout)
#     205         except ConnectionError as e:
#     206             # For a connection error, if it looks like it's a DNS
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/vendored/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/vendored/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/vendored/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/site-packages/botocore/vendored/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     370         try:
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#     374                 httplib_response = conn.getresponse()
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     764                     "non-zero flags not allowed in calls to recv() on %s" %
#     765                     self.__class__)
# --> 766             return self.read(buflen)
#     767         else:
#     768             return self._sock.recv(buflen, flags)
#
# /Users/justw/anaconda/envs/dsci6007/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     651                 v = self._sslobj.read(len, buffer)
#     652             else:
# --> 653                 v = self._sslobj.read(len)
#     654             return v
#     655         except SSLError as x:
#
# KeyboardInterrupt:

# %%
# !pip install boto3
